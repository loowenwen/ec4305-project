# %% [markdown]
# # Penalised, PCR, and Stepwise Models for HDB Resale Prices
#
# This notebook implements the following modelling families:
#
# Penalised Regression Models
# - **LASSO**
# - **Ridge**
# - **Elastic Net**
#
# Variable Selection
# - **Forward Stepwise OLS using AIC**
# - **Forward Stepwise OLS using BIC**
#
# Common Settings
# - Target variable: `log_resale_price = log(resale_price)`
# - Train–Test Split: 80/20
# - 5-Fold Cross-Validation for hyperparameter search
# - Performance Metrics: **RMSE and MAE**
# - Penalised models + PCR use **standardised predictors**
# - Stepwise uses a **small interpretable feature set**

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import Lasso, Ridge, ElasticNet, LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.pipeline import Pipeline

# %% [markdown]
# ## Load and Prepare Data

# %%
DATA_PATH = "../data/HDB_data_2021_sample.xlsx"

df = pd.read_excel(DATA_PATH)

# ensure resale_price exists
df = df.dropna(subset=["resale_price"])

# target variable: log(price)
df["log_resale_price"] = np.log(df["resale_price"])

# predictors for penalised models & PCR
drop_cols_full = ["resale_price", "log_resale_price", "year"]
drop_cols_full = [c for c in drop_cols_full if c in df.columns]

X_full = df.drop(columns=drop_cols_full)
y = df["log_resale_price"].values

feature_names_full = X_full.columns.tolist()

print("Number of observations:", X_full.shape[0])
print("Number of predictors (full):", X_full.shape[1])
# Out:
# Number of observations: 6000
# Number of predictors (full): 228

# %% [markdown]
# ## Train–Test Split & Scaling

# %%
# 80/20 split
X_full_train, X_full_test, y_train, y_test = train_test_split(
    X_full, y, test_size=0.2, random_state=42
)

# standardisation (important for penalised models and PCA)
scaler = StandardScaler()
X_full_train_scaled = scaler.fit_transform(X_full_train)
X_full_test_scaled = scaler.transform(X_full_test)

# performance metrics
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def mae(y_true, y_pred):
    return mean_absolute_error(y_true, y_pred)

def r2(y_true, y_pred):
    return r2_score(y_true, y_pred)

# %% [markdown]
# ## Helper: Penalised Model Runner

# %%
from sklearn.model_selection import GridSearchCV

def run_penalised_model(model_name, base_model, param_grid,
                        X_train, y_train, X_test, y_test, feature_names):

    print(f"\n=== {model_name} ===")

    # baseline model (default hyperparameters)
    base_model.fit(X_train, y_train)
    y_pred_base = base_model.predict(X_test)

    baseline_rmse = rmse(y_test, y_pred_base)
    baseline_mae  = mae(y_test, y_pred_base)
    baseline_r2   = r2(y_test, y_pred_base)

    print(f"{model_name} Baseline - Test RMSE: {baseline_rmse:.4f}, "
          f"MAE: {baseline_mae:.4f}, R²: {baseline_r2:.4f}")

    # hyperparameter tuning via CV
    grid = GridSearchCV(
        estimator=base_model,
        param_grid=param_grid,
        scoring="neg_mean_squared_error",  # RMSE-based CV
        cv=5,
        n_jobs=-1
    )
    grid.fit(X_train, y_train)

    best_model = grid.best_estimator_
    y_pred_best = best_model.predict(X_test)

    tuned_rmse = rmse(y_test, y_pred_best)
    tuned_mae  = mae(y_test, y_pred_best)
    tuned_r2   = r2(y_test, y_pred_best)

    print(f"{model_name} Tuned - Best Params: {grid.best_params_}")
    print(f"{model_name} Tuned - Test RMSE: {tuned_rmse:.4f}, "
          f"MAE: {tuned_mae:.4f}, R²: {tuned_r2:.4f}")

    # coefficients / feature importance (for penalised models)
    if hasattr(best_model, "coef_"):
        coefs = pd.Series(best_model.coef_, index=feature_names)

        print(f"\nTop 10 {model_name} Coefficients (by absolute magnitude):")
        print(coefs.abs().sort_values(ascending=False).head(10))
    else:
        print(f"\n{model_name} has no .coef_ attribute (skipping coefficient summary).")

    # return structured output
    return {
        "best_model": best_model,
        "baseline_rmse": baseline_rmse,
        "baseline_mae": baseline_mae,
        "baseline_r2": baseline_r2,
        "tuned_rmse": tuned_rmse,
        "tuned_mae": tuned_mae,
        "tuned_r2": tuned_r2,
        "best_params": grid.best_params_
    }

# %% [markdown]
# ## Penalised Models: LASSO, Ridge, Elastic Net

# %%
results = []  # store final results

# LASSO
lasso_base = Lasso(max_iter=5000, random_state=42)
lasso_grid = {"alpha": [0.0005, 0.001, 0.01, 0.1, 1.0]}

lasso_res = run_penalised_model(
    "LASSO", lasso_base, lasso_grid,
    X_full_train_scaled, y_train,
    X_full_test_scaled, y_test,
    feature_names_full
)

results.append({
    "Model": "LASSO",
    "Test_RMSE": lasso_res["tuned_rmse"],
    "Test_MAE": lasso_res["tuned_mae"],
    "Test_R2": lasso_res["tuned_r2"],
    "Best_Params": lasso_res["best_params"]
})


# Ridge
ridge_base = Ridge()
ridge_grid = {"alpha": [0.1, 1.0, 10.0, 100.0]}

ridge_res = run_penalised_model(
    "Ridge", ridge_base, ridge_grid,
    X_full_train_scaled, y_train,
    X_full_test_scaled, y_test,
    feature_names_full
)

results.append({
    "Model": "Ridge",
    "Test_RMSE": ridge_res["tuned_rmse"],
    "Test_MAE": ridge_res["tuned_mae"],
    "Test_R2": ridge_res["tuned_r2"],
    "Best_Params": ridge_res["best_params"]
})


# Elastic Net
enet_base = ElasticNet(max_iter=5000, random_state=42)
enet_grid = {"alpha": [0.0005, 0.001, 0.01, 0.1, 1.0],
             "l1_ratio": [0.2, 0.5, 0.8]}

enet_res = run_penalised_model(
    "ElasticNet", enet_base, enet_grid,
    X_full_train_scaled, y_train,
    X_full_test_scaled, y_test,
    feature_names_full
)

results.append({
    "Model": "Elastic Net",
    "Test_RMSE": enet_res["tuned_rmse"],
    "Test_MAE": enet_res["tuned_mae"],
    "Test_R2": enet_res["tuned_r2"],
    "Best_Params": enet_res["best_params"]
})
# Out:
# === LASSO ===
# LASSO Baseline - Test RMSE: 0.3236, MAE: 0.2571, R²: -0.0018
# LASSO Tuned - Best Params: {'alpha': 0.0005}
# LASSO Tuned - Test RMSE: 0.0774, MAE: 0.0599, R²: 0.9426
#
# Top 10 LASSO Coefficients (by absolute magnitude):
# floor_area_sqm           0.178885
# Remaining_lease          0.154745
# Dist_CBD                 0.062814
# mature                   0.031116
# Dist_nearest_GHawker     0.030710
# storey_range_01.TO.03    0.027989
# flat_type_3.ROOM         0.027887
# max_floor_lvl            0.026193
# Dist_nearest_station     0.025844
# postal_2digits_44        0.024547
# dtype: float64
#
# === Ridge ===
# Ridge Baseline - Test RMSE: 0.0773, MAE: 0.0595, R²: 0.9428
# Ridge Tuned - Best Params: {'alpha': 1.0}
# Ridge Tuned - Test RMSE: 0.0773, MAE: 0.0595, R²: 0.9428
#
# Top 10 Ridge Coefficients (by absolute magnitude):
# floor_area_sqm             0.162985
# Remaining_lease            0.153364
# Dist_CBD                   0.097727
# Dist_nearest_GAI_jc        0.073005
# Dist_nearest_university    0.071881
# Dist_nearest_jc            0.042982
# flat_type_3.ROOM           0.036832
# Dist_nearest_G_jc          0.034055
# Dist_nearest_station       0.034002
# flat_type_5.ROOM           0.030627
# dtype: float64
#
# === ElasticNet ===
# ElasticNet Baseline - Test RMSE: 0.3236, MAE: 0.2571, R²: -0.0018
# ElasticNet Tuned - Best Params: {'alpha': 0.0005, 'l1_ratio': 0.2}
# ElasticNet Tuned - Test RMSE: 0.0771, MAE: 0.0594, R²: 0.9431
#
# Top 10 ElasticNet Coefficients (by absolute magnitude):
# floor_area_sqm             0.165953
# Remaining_lease            0.153395
# Dist_CBD                   0.086982
# Dist_nearest_GAI_jc        0.040341
# mature                     0.037534
# Dist_nearest_university    0.034679
# flat_type_3.ROOM           0.033808
# Dist_nearest_station       0.031461
# flat_type_5.ROOM           0.030557
# storey_range_01.TO.03      0.028541
# dtype: float64

# %% [markdown]
# ## Stepwise Feature Subset (Interpretable Variables)

# %%
X_full_train_scaled_df = pd.DataFrame(
    X_full_train_scaled,
    columns=feature_names_full
)

# %% [markdown]
# ## Compute AIC/BIC

# %%
def compute_ic(y_true, y_pred, k, criterion="AIC"):
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    n = y_true.shape[0]

    rss = np.sum((y_true - y_pred)**2)
    sigma2 = rss / n

    loglik = -0.5 * n * (np.log(2 * np.pi * sigma2) + 1)

    if criterion.upper() == "AIC":
        return 2 * k - 2 * loglik
    else:
        return k * np.log(n) - 2 * loglik

# %% [markdown]
# ## Forward Stepwise (AIC/BIC)

# %%
def forward_stepwise_ic(X, y, criteria=("AIC", "BIC"), tol=1e-4, verbose=False):
    # pre-convert for speed
    X_np = X.values
    y_np = y.values if isinstance(y, pd.Series) else y
    feature_names = list(X.columns)
    n_features = len(feature_names)

    results = {}

    for criterion in criteria:

        print(f"\n=== Forward Stepwise Selection using {criterion} ===")
        
        selected = []
        remaining = feature_names.copy()
        best_ic = np.inf

        while remaining:
            ic_candidates = []

            for feat in remaining:
                trial_features = selected + [feat]
                idx = [X.columns.get_loc(f) for f in trial_features]
                X_trial = X_np[:, idx]

                model = LinearRegression()
                model.fit(X_trial, y_np)
                y_pred = model.predict(X_trial)

                k = len(trial_features) + 1
                ic_val = compute_ic(y_np, y_pred, k, criterion)
                r2_val = r2_score(y_np, y_pred)

                ic_candidates.append((ic_val, feat, r2_val))

                if verbose:
                    print(f"{criterion}: {feat:>25s} -> {ic_val:.4f}, R²={r2_val:.4f}")

            ic_candidates.sort(key=lambda x: x[0])
            best_new_ic, best_feat, best_r2 = ic_candidates[0]

            if best_new_ic + tol < best_ic:
                selected.append(best_feat)
                remaining.remove(best_feat)
                best_ic = best_new_ic

                print(f"--> Added {best_feat}, {criterion}={best_new_ic:.4f}, R²={best_r2:.4f}")
            else:
                print(f"No improvement in {criterion}. Stopping.")
                break

        results[criterion] = {
            "selected": selected,
            "best_ic": best_ic
        }

    return results

# %%
stepwise_results = forward_stepwise_ic(
    X_full_train_scaled_df,
    y_train,
    criteria=("AIC", "BIC"),
    verbose=False   # True if you want every trial printed
)
# Out:
# === Forward Stepwise Selection using AIC ===
# --> Added floor_area_sqm, AIC=-379.9940, R²=0.4656
# --> Added max_floor_lvl, AIC=-3148.6260, R²=0.7000
# --> Added Dist_CBD, AIC=-3903.5809, R²=0.7437
# --> Added Remaining_lease, AIC=-5969.3479, R²=0.8334
# --> Added LRT, AIC=-6607.1883, R²=0.8542
# --> Added unique_no_mrt_0.5km, AIC=-6963.2867, R²=0.8647
# --> Added flat_model_dbss, AIC=-7339.3979, R²=0.8749
# --> Added town_SENGKANG, AIC=-7589.6355, R²=0.8813
# --> Added storey_range_01.TO.03, AIC=-7770.2382, R²=0.8858
# --> Added mature, AIC=-7933.3352, R²=0.8896
# --> Added postal_2digits_44, AIC=-8063.1946, R²=0.8926
# --> Added Dist_nearest_station, AIC=-8238.8809, R²=0.8965
# --> Added Nearest_A_hospital_ownership_Private, AIC=-8392.0937, R²=0.8998
# --> Added Dist_nearest_GHawker, AIC=-8539.5560, R²=0.9029
# --> Added flat_model_terrace, AIC=-8668.7121, R²=0.9055
# --> Added storey_range_04.TO.06, AIC=-8793.4797, R²=0.9080
# --> Added town_BUKIT.TIMAH, AIC=-8916.5435, R²=0.9103
# --> Added beach_within_2km, AIC=-9031.8651, R²=0.9125
# --> Added unique_no_mrt_1km, AIC=-9156.5030, R²=0.9148
# --> Added postal_2digits_57, AIC=-9260.7288, R²=0.9166
# --> Added flat_type_2.ROOM, AIC=-9365.7197, R²=0.9185
# --> Added storey_range_07.TO.09, AIC=-9451.3450, R²=0.9200
# --> Added postal_2digits_76, AIC=-9516.4258, R²=0.9211
# --> Added EWL, AIC=-9605.1442, R²=0.9225
# --> Added flat_model_new.generation, AIC=-9678.1072, R²=0.9237
# --> Added flat_model_simplified, AIC=-9753.1861, R²=0.9250
# --> Added storey_range_10.TO.12, AIC=-9819.7601, R²=0.9260
# --> Added postal_2digits_79, AIC=-9881.8866, R²=0.9270
# --> Added postal_2digits_39, AIC=-9935.4245, R²=0.9278
# --> Added Dist_nearest_polytechnic, AIC=-9990.5486, R²=0.9287
# --> Added month_Jan, AIC=-10038.6032, R²=0.9294
# --> Added total_dwelling_units, AIC=-10087.1994, R²=0.9302
# --> Added flat_model_premium.apartment, AIC=-10136.7589, R²=0.9309
# --> Added town_GEYLANG, AIC=-10177.7840, R²=0.9315
# --> Added CCL, AIC=-10223.8625, R²=0.9322
# --> Added flat_model_maisonette, AIC=-10263.4778, R²=0.9328
# --> Added flat_type_3.ROOM, AIC=-10306.2001, R²=0.9334
# --> Added storey_range_13.TO.15, AIC=-10344.9607, R²=0.9340
# --> Added storey_range_16.TO.18, AIC=-10376.3082, R²=0.9345
# --> Added ADF_within_1km, AIC=-10407.3818, R²=0.9349
# --> Added flat_model_model.a.maisonette, AIC=-10435.4115, R²=0.9353
# --> Added postal_2digits_50, AIC=-10461.5318, R²=0.9357
# --> Added Dist_nearest_GAI_secondary_school, AIC=-10491.2290, R²=0.9361
# --> Added postal_2digits_47, AIC=-10521.8776, R²=0.9365
# --> Added Dist_nearest_CC, AIC=-10553.2894, R²=0.9370
# --> Added town_KALLANG.WHAMPOA, AIC=-10583.9183, R²=0.9374
# --> Added flat_type_4.ROOM, AIC=-10608.2329, R²=0.9378
# --> Added flat_model_apartment, AIC=-10631.9579, R²=0.9381
# --> Added flat_type_1.ROOM, AIC=-10662.4973, R²=0.9385
# --> Added no_malls_0.5km, AIC=-10684.3044, R²=0.9388
# --> Added flat_model_improved, AIC=-10704.0569, R²=0.9391
# --> Added month_Feb, AIC=-10719.3365, R²=0.9393
# --> Added X4room_sold, AIC=-10735.4426, R²=0.9395
# --> Added flat_model_adjoined.flat, AIC=-10747.8994, R²=0.9397
# --> Added nearest_ghawker_no_of_mkt_produce_stalls, AIC=-10760.3561, R²=0.9399
# --> Added town_CENTRAL.AREA, AIC=-10775.4071, R²=0.9401
# --> Added no_primary_schools_1km, AIC=-10792.1595, R²=0.9403
# --> Added flat_type_MULTI.GENERATION, AIC=-10805.7335, R²=0.9405
# --> Added postal_2digits_65, AIC=-10818.8622, R²=0.9407
# --> Added NEL, AIC=-10839.2385, R²=0.9410
# --> Added postal_2digits_16, AIC=-10855.9551, R²=0.9412
# --> Added postal_2digits_08, AIC=-10867.4875, R²=0.9414
# --> Added flat_model_improved.maisonette, AIC=-10877.4272, R²=0.9415
# --> Added postal_2digits_75, AIC=-10887.4136, R²=0.9417
# --> Added town_BEDOK, AIC=-10897.3647, R²=0.9418
# --> Added Nearest_A_hospital_ownership_Non.profit, AIC=-10909.1279, R²=0.9420
# --> Added no_GAI_primary_schools_2km, AIC=-10927.7883, R²=0.9422
# --> Added Dist_nearest_G_secondary_school, AIC=-10937.9733, R²=0.9424
# --> Added postal_2digits_30, AIC=-10947.5976, R²=0.9425
# --> Added month_May, AIC=-10956.5413, R²=0.9427
# --> Added town_TOA.PAYOH, AIC=-10963.6548, R²=0.9428
# --> Added postal_2digits_40, AIC=-10973.0701, R²=0.9429
# --> Added Dist_nearest_secondary_school, AIC=-10981.4628, R²=0.9430
# --> Added postal_2digits_33, AIC=-10990.8077, R²=0.9432
# --> Added postal_2digits_18, AIC=-10997.8748, R²=0.9433
# --> Added no_malls_2km, AIC=-11006.8120, R²=0.9434
# --> Added postal_2digits_37, AIC=-11012.5682, R²=0.9435
# --> Added flat_model_premium.apartment.loft, AIC=-11018.5713, R²=0.9436
# --> Added postal_2digits_32, AIC=-11023.2622, R²=0.9437
# --> Added postal_2digits_38, AIC=-11029.2266, R²=0.9438
# --> Added Dist_nearest_ADF, AIC=-11033.7473, R²=0.9438
# --> Added ADF_within_2km, AIC=-11047.3467, R²=0.9440
# --> Added postal_2digits_60, AIC=-11055.4633, R²=0.9441
# --> Added postal_2digits_12, AIC=-11061.7643, R²=0.9442
# --> Added postal_2digits_21, AIC=-11067.5260, R²=0.9443
# --> Added postal_2digits_27, AIC=-11073.5679, R²=0.9444
# --> Added Dist_nearest_beach, AIC=-11076.5268, R²=0.9445
# --> Added Dist_nearest_hospital, AIC=-11081.7155, R²=0.9446
# --> Added Dist_nearest_university, AIC=-11086.4746, R²=0.9446
# --> Added postal_2digits_68, AIC=-11092.4480, R²=0.9447
# --> Added Dist_nearest_GAI_jc, AIC=-11097.3118, R²=0.9448
# --> Added postal_2digits_13, AIC=-11112.1307, R²=0.9450
# --> Added postal_2digits_14, AIC=-11116.3667, R²=0.9451
# --> Added town_SERANGOON, AIC=-11120.9706, R²=0.9451
# --> Added postal_2digits_09, AIC=-11126.3607, R²=0.9452
# --> Added Nearest_GAI_secondary_school_gender_BOYS..SCHOOL, AIC=-11131.0168, R²=0.9453
# --> Added Nearest_GAI_primary_school_gender_BOYS..SCHOOL, AIC=-11135.5908, R²=0.9454
# --> Added X5room_sold, AIC=-11138.2108, R²=0.9454
# --> Added Dist_nearest_jc, AIC=-11141.1887, R²=0.9455
# --> Added Dist_nearest_G_jc, AIC=-11154.3379, R²=0.9457
# --> Added postal_2digits_46, AIC=-11158.7361, R²=0.9457
# --> Added postal_2digits_82, AIC=-11161.3923, R²=0.9458
# --> Added town_JURONG.WEST, AIC=-11164.8716, R²=0.9458
# --> Added flat_model_2.room, AIC=-11167.5139, R²=0.9459
# --> Added X2room_rental, AIC=-11169.3833, R²=0.9459
# --> Added no_primary_schools_2km, AIC=-11171.0766, R²=0.9460
# --> Added flat_model_premium.maisonette, AIC=-11172.4385, R²=0.9460
# --> Added Dist_nearest_A_hospital, AIC=-11173.7841, R²=0.9461
# --> Added postal_2digits_67, AIC=-11176.5578, R²=0.9461
# --> Added NSL, AIC=-11179.2962, R²=0.9462
# --> Added Dist_nearest_GAI_primary_school, AIC=-11179.7793, R²=0.9462
# --> Added waterbody_within_2km, AIC=-11181.7972, R²=0.9462
# --> Added town_HOUGANG, AIC=-11183.8708, R²=0.9463
# --> Added postal_2digits_51, AIC=-11184.7044, R²=0.9463
# --> Added postal_2digits_52, AIC=-11188.1943, R²=0.9464
# --> Added nearest_ghawker_no_of_cooked_food_stalls, AIC=-11190.4647, R²=0.9464
# --> Added Nearest_secondary_school_gender_CO.ED.SCHOOL, AIC=-11192.9098, R²=0.9465
# --> Added storey_range_19.TO.21, AIC=-11193.5370, R²=0.9465
# --> Added flat_model_type.s2, AIC=-11194.1513, R²=0.9465
# --> Added postal_2digits_43, AIC=-11194.7552, R²=0.9466
# --> Added X2room_sold, AIC=-11194.7812, R²=0.9466
# --> Added X3room_sold, AIC=-11194.9467, R²=0.9466
# No improvement in AIC. Stopping.
#
# === Forward Stepwise Selection using BIC ===
# --> Added floor_area_sqm, BIC=-367.0413, R²=0.4656
# --> Added max_floor_lvl, BIC=-3129.1969, R²=0.7000
# --> Added Dist_CBD, BIC=-3877.6754, R²=0.7437
# --> Added Remaining_lease, BIC=-5936.9660, R²=0.8334
# --> Added LRT, BIC=-6568.3300, R²=0.8542
# --> Added unique_no_mrt_0.5km, BIC=-6917.9521, R²=0.8647
# --> Added flat_model_dbss, BIC=-7287.5869, R²=0.8749
# --> Added town_SENGKANG, BIC=-7531.3482, R²=0.8813
# --> Added storey_range_01.TO.03, BIC=-7705.4745, R²=0.8858
# --> Added mature, BIC=-7862.0951, R²=0.8896
# --> Added postal_2digits_44, BIC=-7985.4782, R²=0.8926
# --> Added Dist_nearest_station, BIC=-8154.6881, R²=0.8965
# --> Added Nearest_A_hospital_ownership_Private, BIC=-8301.4245, R²=0.8998
# --> Added Dist_nearest_GHawker, BIC=-8442.4105, R²=0.9029
# --> Added flat_model_terrace, BIC=-8565.0902, R²=0.9055
# --> Added storey_range_04.TO.06, BIC=-8683.3814, R²=0.9080
# --> Added town_BUKIT.TIMAH, BIC=-8799.9688, R²=0.9103
# --> Added beach_within_2km, BIC=-8908.8141, R²=0.9125
# --> Added unique_no_mrt_1km, BIC=-9026.9756, R²=0.9148
# --> Added postal_2digits_57, BIC=-9124.7250, R²=0.9166
# --> Added flat_type_2.ROOM, BIC=-9223.2395, R²=0.9185
# --> Added storey_range_07.TO.09, BIC=-9302.3884, R²=0.9200
# --> Added postal_2digits_76, BIC=-9360.9929, R²=0.9211
# --> Added EWL, BIC=-9443.2349, R²=0.9225
# --> Added flat_model_new.generation, BIC=-9509.7216, R²=0.9237
# --> Added flat_model_simplified, BIC=-9578.3241, R²=0.9250
# --> Added storey_range_10.TO.12, BIC=-9638.4217, R²=0.9260
# --> Added postal_2digits_79, BIC=-9694.0719, R²=0.9270
# --> Added postal_2digits_39, BIC=-9741.1334, R²=0.9278
# --> Added Dist_nearest_polytechnic, BIC=-9789.7811, R²=0.9287
# --> Added month_Jan, BIC=-9831.3593, R²=0.9294
# --> Added total_dwelling_units, BIC=-9873.4791, R²=0.9302
# --> Added flat_model_premium.apartment, BIC=-9916.5623, R²=0.9309
# --> Added town_GEYLANG, BIC=-9951.1110, R²=0.9315
# --> Added CCL, BIC=-9990.7131, R²=0.9322
# --> Added flat_model_maisonette, BIC=-10023.8520, R²=0.9328
# --> Added flat_type_3.ROOM, BIC=-10060.0980, R²=0.9334
# --> Added storey_range_13.TO.15, BIC=-10092.3823, R²=0.9340
# --> Added storey_range_16.TO.18, BIC=-10117.2534, R²=0.9345
# --> Added ADF_within_1km, BIC=-10141.8505, R²=0.9349
# --> Added flat_model_model.a.maisonette, BIC=-10163.4039, R²=0.9353
# --> Added postal_2digits_50, BIC=-10183.0479, R²=0.9357
# --> Added Dist_nearest_GAI_secondary_school, BIC=-10206.2687, R²=0.9361
# --> Added postal_2digits_47, BIC=-10230.4409, R²=0.9365
# --> Added Dist_nearest_CC, BIC=-10255.3763, R²=0.9370
# --> Added town_KALLANG.WHAMPOA, BIC=-10279.5288, R²=0.9374
# --> Added flat_type_4.ROOM, BIC=-10297.3670, R²=0.9378
# --> Added flat_model_apartment, BIC=-10314.6157, R²=0.9381
# --> Added flat_type_1.ROOM, BIC=-10338.6787, R²=0.9385
# --> Added no_malls_0.5km, BIC=-10354.0095, R²=0.9388
# --> Added flat_model_improved, BIC=-10367.2856, R²=0.9391
# --> Added month_Feb, BIC=-10376.0888, R²=0.9393
# --> Added X4room_sold, BIC=-10385.7185, R²=0.9395
# --> Added flat_model_adjoined.flat, BIC=-10391.6990, R²=0.9397
# --> Added nearest_ghawker_no_of_mkt_produce_stalls, BIC=-10397.6793, R²=0.9399
# --> Added town_CENTRAL.AREA, BIC=-10406.2540, R²=0.9401
# --> Added no_primary_schools_1km, BIC=-10416.5300, R²=0.9403
# --> Added flat_type_MULTI.GENERATION, BIC=-10423.6276, R²=0.9405
# --> Added postal_2digits_65, BIC=-10430.2800, R²=0.9407
# --> Added NEL, BIC=-10444.1798, R²=0.9410
# --> Added postal_2digits_16, BIC=-10454.4201, R²=0.9412
# --> Added postal_2digits_08, BIC=-10459.4761, R²=0.9414
# --> Added flat_model_improved.maisonette, BIC=-10462.9394, R²=0.9415
# --> Added postal_2digits_75, BIC=-10466.4495, R²=0.9417
# --> Added town_BEDOK, BIC=-10469.9242, R²=0.9418
# --> Added Nearest_A_hospital_ownership_Non.profit, BIC=-10475.2110, R²=0.9420
# --> Added no_GAI_primary_schools_2km, BIC=-10487.3950, R²=0.9422
# --> Added Dist_nearest_G_secondary_school, BIC=-10491.1037, R²=0.9424
# --> Added postal_2digits_30, BIC=-10494.2516, R²=0.9425
# --> Added month_May, BIC=-10496.7190, R²=0.9427
# --> Added town_TOA.PAYOH, BIC=-10497.3561, R²=0.9428
# --> Added postal_2digits_40, BIC=-10500.2950, R²=0.9429
# --> Added Dist_nearest_secondary_school, BIC=-10502.2113, R²=0.9430
# --> Added postal_2digits_33, BIC=-10505.0798, R²=0.9432
# --> Added postal_2digits_18, BIC=-10505.6706, R²=0.9433
# --> Added no_malls_2km, BIC=-10508.1314, R²=0.9434
# No improvement in BIC. Stopping.

# %%
def evaluate_stepwise_model(X_train, y_train, X_test, y_test, selected):
    Xtr = X_train[selected]
    Xte = X_test[selected]

    model = LinearRegression()
    model.fit(Xtr, y_train)
    y_pred = model.predict(Xte)

    return {
        "RMSE": rmse(y_test, y_pred),
        "MAE": mae(y_test, y_pred),
        "R2": r2(y_test, y_pred),
        "model": model
    }

# %%
# after scaling
X_full_train_scaled_df = pd.DataFrame(
    X_full_train_scaled,
    columns=feature_names_full
)

X_full_test_scaled_df = pd.DataFrame(
    X_full_test_scaled,
    columns=feature_names_full
)

# evaluate AIC-selected model
aic_feats = stepwise_results["AIC"]["selected"]

aic_eval = evaluate_stepwise_model(
    X_full_train_scaled_df, y_train,
    X_full_test_scaled_df, y_test,
    aic_feats
)

# evaluate BIC-selected model
bic_feats = stepwise_results["BIC"]["selected"]

bic_eval = evaluate_stepwise_model(
    X_full_train_scaled_df, y_train,
    X_full_test_scaled_df, y_test,
    bic_feats
)

# %% [markdown]
# ## Summary Table

# %%
results_df = pd.DataFrame(results)
results_df.sort_values("Test_RMSE")
# Out:
#          Model  Test_RMSE  Test_MAE   Test_R2  \
# 2  Elastic Net   0.077115  0.059360  0.943114
# 1        Ridge   0.077322  0.059510  0.942808
# 0        LASSO   0.077444  0.059862  0.942628
#
#                           Best_Params
# 2  {'alpha': 0.0005, 'l1_ratio': 0.2}
# 1                      {'alpha': 1.0}
# 0                   {'alpha': 0.0005}

# %%
aic_eval["RMSE"], aic_eval["MAE"], aic_eval["R2"], bic_eval["RMSE"], bic_eval["MAE"], bic_eval["R2"]
# Out:
# (np.float64(0.07732082902614039),
#  0.05971598207135164,
#  0.9428099443364082,
#  np.float64(0.07910787705223886),
#  0.06166227947239733,
#  0.9401358286432576)

# %%
print("AIC selected:", len(stepwise_results["AIC"]["selected"]), "features")
print("AIC-selected features:")
for f in stepwise_results["AIC"]["selected"]:
    print(f)

print("-------------------------------------------------------------------")

print("BIC selected:", len(stepwise_results["BIC"]["selected"]), "features")
print("\nBIC-selected features:")
for f in stepwise_results["BIC"]["selected"]:
    print(f)
# Out:
# AIC selected: 122 features
# AIC-selected features:
# floor_area_sqm
# max_floor_lvl
# Dist_CBD
# Remaining_lease
# LRT
# unique_no_mrt_0.5km
# flat_model_dbss
# town_SENGKANG
# storey_range_01.TO.03
# mature
# postal_2digits_44
# Dist_nearest_station
# Nearest_A_hospital_ownership_Private
# Dist_nearest_GHawker
# flat_model_terrace
# storey_range_04.TO.06
# town_BUKIT.TIMAH
# beach_within_2km
# unique_no_mrt_1km
# postal_2digits_57
# flat_type_2.ROOM
# storey_range_07.TO.09
# postal_2digits_76
# EWL
# flat_model_new.generation
# flat_model_simplified
# storey_range_10.TO.12
# postal_2digits_79
# postal_2digits_39
# Dist_nearest_polytechnic
# month_Jan
# total_dwelling_units
# flat_model_premium.apartment
# town_GEYLANG
# CCL
# flat_model_maisonette
# flat_type_3.ROOM
# storey_range_13.TO.15
# storey_range_16.TO.18
# ADF_within_1km
# flat_model_model.a.maisonette
# postal_2digits_50
# Dist_nearest_GAI_secondary_school
# postal_2digits_47
# Dist_nearest_CC
# town_KALLANG.WHAMPOA
# flat_type_4.ROOM
# flat_model_apartment
# flat_type_1.ROOM
# no_malls_0.5km
# flat_model_improved
# month_Feb
# X4room_sold
# flat_model_adjoined.flat
# nearest_ghawker_no_of_mkt_produce_stalls
# town_CENTRAL.AREA
# no_primary_schools_1km
# flat_type_MULTI.GENERATION
# postal_2digits_65
# NEL
# postal_2digits_16
# postal_2digits_08
# flat_model_improved.maisonette
# postal_2digits_75
# town_BEDOK
# Nearest_A_hospital_ownership_Non.profit
# no_GAI_primary_schools_2km
# Dist_nearest_G_secondary_school
# postal_2digits_30
# month_May
# town_TOA.PAYOH
# postal_2digits_40
# Dist_nearest_secondary_school
# postal_2digits_33
# postal_2digits_18
# no_malls_2km
# postal_2digits_37
# flat_model_premium.apartment.loft
# postal_2digits_32
# postal_2digits_38
# Dist_nearest_ADF
# ADF_within_2km
# postal_2digits_60
# postal_2digits_12
# postal_2digits_21
# postal_2digits_27
# Dist_nearest_beach
# Dist_nearest_hospital
# Dist_nearest_university
# postal_2digits_68
# Dist_nearest_GAI_jc
# postal_2digits_13
# postal_2digits_14
# town_SERANGOON
# postal_2digits_09
# Nearest_GAI_secondary_school_gender_BOYS..SCHOOL
# Nearest_GAI_primary_school_gender_BOYS..SCHOOL
# X5room_sold
# Dist_nearest_jc
# Dist_nearest_G_jc
# postal_2digits_46
# postal_2digits_82
# town_JURONG.WEST
# flat_model_2.room
# X2room_rental
# no_primary_schools_2km
# flat_model_premium.maisonette
# Dist_nearest_A_hospital
# postal_2digits_67
# NSL
# Dist_nearest_GAI_primary_school
# waterbody_within_2km
# town_HOUGANG
# postal_2digits_51
# postal_2digits_52
# nearest_ghawker_no_of_cooked_food_stalls
# Nearest_secondary_school_gender_CO.ED.SCHOOL
# storey_range_19.TO.21
# flat_model_type.s2
# postal_2digits_43
# X2room_sold
# X3room_sold
# -------------------------------------------------------------------
# BIC selected: 76 features
#
# BIC-selected features:
# floor_area_sqm
# max_floor_lvl
# Dist_CBD
# Remaining_lease
# LRT
# unique_no_mrt_0.5km
# flat_model_dbss
# town_SENGKANG
# storey_range_01.TO.03
# mature
# postal_2digits_44
# Dist_nearest_station
# Nearest_A_hospital_ownership_Private
# Dist_nearest_GHawker
# flat_model_terrace
# storey_range_04.TO.06
# town_BUKIT.TIMAH
# beach_within_2km
# unique_no_mrt_1km
# postal_2digits_57
# flat_type_2.ROOM
# storey_range_07.TO.09
# postal_2digits_76
# EWL
# flat_model_new.generation
# flat_model_simplified
# storey_range_10.TO.12
# postal_2digits_79
# postal_2digits_39
# Dist_nearest_polytechnic
# month_Jan
# total_dwelling_units
# flat_model_premium.apartment
# town_GEYLANG
# CCL
# flat_model_maisonette
# flat_type_3.ROOM
# storey_range_13.TO.15
# storey_range_16.TO.18
# ADF_within_1km
# flat_model_model.a.maisonette
# postal_2digits_50
# Dist_nearest_GAI_secondary_school
# postal_2digits_47
# Dist_nearest_CC
# town_KALLANG.WHAMPOA
# flat_type_4.ROOM
# flat_model_apartment
# flat_type_1.ROOM
# no_malls_0.5km
# flat_model_improved
# month_Feb
# X4room_sold
# flat_model_adjoined.flat
# nearest_ghawker_no_of_mkt_produce_stalls
# town_CENTRAL.AREA
# no_primary_schools_1km
# flat_type_MULTI.GENERATION
# postal_2digits_65
# NEL
# postal_2digits_16
# postal_2digits_08
# flat_model_improved.maisonette
# postal_2digits_75
# town_BEDOK
# Nearest_A_hospital_ownership_Non.profit
# no_GAI_primary_schools_2km
# Dist_nearest_G_secondary_school
# postal_2digits_30
# month_May
# town_TOA.PAYOH
# postal_2digits_40
# Dist_nearest_secondary_school
# postal_2digits_33
# postal_2digits_18
# no_malls_2km
